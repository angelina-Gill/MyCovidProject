# %%
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
dataset_Covid19 = pd.read_csv(r'D:\python\classifire_d.csv')

dataset_Covid19.head()
# Out:
#          Date     Time State/UnionTerritory ConfirmedIndianNational  Gender  \
# 0  19-03-2020  6:00 PM           Chandigarh                       1  Female
# 1  20-03-2020  6:00 PM           Chandigarh                       1    Male
# 2  21-03-2020  6:00 PM           Chandigarh                       1  Female
# 3  22-03-2020  6:00 PM           Chandigarh                       5  Female
# 4  23-03-2020  6:00 PM           Chandigarh                       6  Female
#
#   ConfirmedForeignNational  Age                             Serious symptoms  \
# 0                        0   18                       chest pain or pressure
# 1                        0   86                   loss of speech or movement
# 2                        0   62                   loss of speech or movement
# 3                        0   80  difficulty breathing or shortness of breath
# 4                        0   89                       chest pain or pressure
#
# ...

# %%
X = dataset_Covid19.iloc[:,:-1].values 
y = dataset_Covid19.iloc[:,4].values 
dataset_Covid19.head()
# Out:
#          Date     Time State/UnionTerritory ConfirmedIndianNational  Gender  \
# 0  19-03-2020  6:00 PM           Chandigarh                       1  Female
# 1  20-03-2020  6:00 PM           Chandigarh                       1    Male
# 2  21-03-2020  6:00 PM           Chandigarh                       1  Female
# 3  22-03-2020  6:00 PM           Chandigarh                       5  Female
# 4  23-03-2020  6:00 PM           Chandigarh                       6  Female
#
#   ConfirmedForeignNational  Age                             Serious symptoms  \
# 0                        0   18                       chest pain or pressure
# 1                        0   86                   loss of speech or movement
# 2                        0   62                   loss of speech or movement
# 3                        0   80  difficulty breathing or shortness of breath
# 4                        0   89                       chest pain or pressure
#
# ...

# %%
dataset_Covid19.describe()
# Out:
#               Age
# count   91.000000
# mean    54.769231
# std     27.313845
# min      5.000000
# 25%     36.500000
# 50%     57.000000
# 75%     78.500000
# max    100.000000

# %%
dataset_Covid19
# Out:
#           Date     Time State/UnionTerritory ConfirmedIndianNational  Gender  \
# 0   19-03-2020  6:00 PM           Chandigarh                       1  Female
# 1   20-03-2020  6:00 PM           Chandigarh                       1    Male
# 2   21-03-2020  6:00 PM           Chandigarh                       1  Female
# 3   22-03-2020  6:00 PM           Chandigarh                       5  Female
# 4   23-03-2020  6:00 PM           Chandigarh                       6  Female
# ..         ...      ...                  ...                     ...     ...
# 86  13-06-2020  8:00 AM           Chandigarh                       -  Female
# 87  14-06-2020  8:00 AM           Chandigarh                       -  Female
# 88  15-06-2020  8:00 AM           Chandigarh                       -  Female
# 89  16-06-2020  8:00 AM           Chandigarh                       -  Female
# 90  17-06-2020  8:00 AM           Chandigarh                       -  Female
#
# ...

# %%
print("Features: ", dataset_Covid19.Patient_Status)
print("Labels1: ", dataset_Covid19.Serious_symptoms)
print("Labels2: ", dataset_Covid19.Less_common_symptoms)
print("Labels3: ", dataset_Covid19.Most_common_symptoms)
print("Labels4: ", dataset_Covid19.Severity)
# Out:
# Features:  0       flu
# 1       flu
# 2       flu
# 3       flu
# 4       flu
#       ...
# 86      flu
# 87      flu
# 88    Covid
# 89    Covid
# 90      flu
# Name: Patient_Status, Length: 91, dtype: object
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-dabdc2a62a44> in <module>
#       1 print("Features: ", dataset_Covid19.Patient_Status)
# ----> 2 print("Labels1: ", dataset_Covid19.Serious_symptoms)
#       3 print("Labels2: ", dataset_Covid19.Less_common_symptoms)
#       4 print("Labels3: ", dataset_Covid19.Most_common_symptoms)
#       5 print("Labels4: ", dataset_Covid19.Severity)
#
# c:\users\hp india\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# ...

# %%
dataset_Covid19.shape
# Out:
# (91, 12)

# %%
print(dataset_Covid19[0:5])
# Out:
#          Date     Time State/UnionTerritory ConfirmedIndianNational  Gender  \
# 0  19-03-2020  6:00 PM           Chandigarh                       1  Female
# 1  20-03-2020  6:00 PM           Chandigarh                       1    Male
# 2  21-03-2020  6:00 PM           Chandigarh                       1  Female
# 3  22-03-2020  6:00 PM           Chandigarh                       5  Female
# 4  23-03-2020  6:00 PM           Chandigarh                       6  Female
#
#   ConfirmedForeignNational  Age                             Serious symptoms  \
# 0                        0   18                       chest pain or pressure
# 1                        0   86                   loss of speech or movement
# 2                        0   62                   loss of speech or movement
# 3                        0   80  difficulty breathing or shortness of breath
# 4                        0   89                       chest pain or pressure
#
# ...

# %%
print(dataset_Covid19.Patient_Status)
# Out:
# 0       flu
# 1       flu
# 2       flu
# 3       flu
# 4       flu
#       ...
# 86      flu
# 87      flu
# 88    Covid
# 89    Covid
# 90      flu
# Name: Patient_Status, Length: 91, dtype: object

# %%
print(dataset_Covid19.target)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-150-3027356433e1> in <module>
# ----> 1 print(dataset_Covid19.target)
#
# c:\users\hp india\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'target'

# %%
from sklearn.model_selection import train_test_split



X_train, X_test, y_train, y_test = train_test_split(dataset_Covid19, dataset_Covid19.Patient_Status, test_size=0.3,random_state=109)

# %%
X = dataset_Covid19['Severity'].values.reshape(-1,1)
y = dataset_Covid19['Patient_Status'].values.reshape(-1,1)

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-149-7c6351379bc1> in <module>
#       6
#       7 #Train the model using the training sets
# ----> 8 clf.fit(X_train, y_train)
#       9
#      10 #Predict the response for test dataset
#
# c:\users\hp india\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     146         X, y = check_X_y(X, y, dtype=np.float64,
#     147                          order='C', accept_sparse='csr',
# --> 148                          accept_large_sparse=False)
#     149         y = self._validate_targets(y)
#     150
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-db8f2dc95be3> in <module>
#       4 a= svm.SVC(kernel='linear')
#       5
# ----> 6 a.fit(X_train, y_train)
#       7
#       8
#
# c:\users\hp india\appdata\local\programs\python\python37\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     146         X, y = check_X_y(X, y, dtype=np.float64,
#     147                          order='C', accept_sparse='csr',
# --> 148                          accept_large_sparse=False)
#     149         y = self._validate_targets(y)
#     150
#
# c:\users\hp india\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
y_pred = dataset_Covid19.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-140-670e058edec8> in <module>
# ----> 1 y_pred = dataset_Covid19.predict(X_test)
#
# c:\users\hp india\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'predict'

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-6bdac31a2444> in <module>
#       3
#       4 # Model Accuracy: how often is the classifier correct?
# ----> 5 print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
#
# NameError: name 'y_pred' is not defined

# %%
# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-dc5a02dabd46> in <module>
#       1 # Model Precision: what percentage of positive tuples are labeled as such?
# ----> 2 print("Precision:",metrics.precision_score(y_test, y_pred))
#       3
#       4 # Model Recall: what percentage of positive tuples are labelled as such?
#       5 print("Recall:",metrics.recall_score(y_test, y_pred))
#
# NameError: name 'y_pred' is not defined
