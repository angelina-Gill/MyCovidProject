# %%
import tkinter as tk 
from tkinter import ttk 
 
top = tk.Tk() 
top.title('Pandemic Analyzer') 
top.geometry("450x300")



 
label1 = tk.Label(top, text= "Select State",fg = 'white').place(x = 80, y = 100) 

label2 = tk.Label(top, text= "Infected",fg = 'yellow').place(x = 80, y = 120) 

label3 = tk.Label(top, text="Recoverd",fg = 'green').place(x = 80, y = 140) 

label4 = tk.Label(top, text= "Deceased",fg = 'Red').place(x = 80, y = 160)

label5 = tk.Label(top, text= "Value",fg = 'blue').place(x = 80, y = 220) 


entry1 = tk.Entry(top, width = 30).place(x = 200, y = 100)   
entry2 = tk.Entry(top, width = 30,bg = 'yellow').place(x = 200, y = 120)  
entry3 = tk.Entry(top, width = 30,bg = 'green') .place(x = 200, y = 140)    
entry4 = tk.Entry(top, width = 30,bg = 'Red').place(x = 200, y =160)  
entry5 = tk.Entry(top, width = 30).place(x = 200, y =220) 

button1 = tk.Button(top, text = 'IMR').place(x = 200,  y = 190) 
button2 = tk.Button(top, text = 'CMR').place(x = 240,  y = 190) 


 # label 
ttk.Label(top, text = "Select the Month :", 
          font = ("Times New Roman", 10)).grid(column = 0, 
          row = 5, padx = 10, pady = 25) 
  
# Combobox creation 
n = tk.StringVar() 
Statechoosen = ttk.Combobox(top, width = 27, textvariable = n) 
# Adding combobox drop down list 
Statechoosen['values'] = ('Maharashtra'
'Tamil Nadu'
'Delhi'
'Gujarat'
'Uttar Pradesh'
'Rajasthan'
'West Bengal'
'Madhya Pradesh'
'Haryana'
'State Unassigned'
'Karnataka'
'Andhra Pradesh'
'Bihar'
'Telangana'
'Jammu and Kashmir'
'Assam'
'Odisha'
'Punjab'
'Kerala'
'Uttarakhand'
'Chhattisgarh'
'Jharkhand'
'Tripura'
'Ladakh'
'Goa'
'Himachal Pradesh'
'Manipur'
'Chandigarh'
'Puducherry'
'Nagaland'
'Mizoram'
'Arunachal Pradesh'
'Sikkim'
'Dadra and Nagar Haveli and Daman and Diu'
'Andaman and Nicobar Islands'
'Meghalaya'
'Lakshadweep')
         
Statechoosen.grid(column = 1, row = 5) 
Statechoosen.current() 

top.mainloop()
