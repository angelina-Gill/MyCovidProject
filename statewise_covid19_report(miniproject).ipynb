# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel ('D:\python\statewisereport.xlsx')
print (df)
# Out:
#             State  Confirmed  Recovered  Deaths  Active
# 0     Maharashtra     206619     111740    8822   86040
# 1      Tamil Nadu     111151      62778    1510   46863
# 2           Delhi      99444      71339    3067   25038
# 3         Gujarat      36123      25900    1944    8279
# 4   Uttar Pradesh      27707      18761     785    8161
# 5       Rajasthan      20263      15965     459    3839
# 6     West Bengal      22126      14711     757    6658
# 7  Madhya Pradesh      14930      11411     608    2911

# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')

x =['5',  '15',  '25',  '30']
y =[206619 ,    111740  ,  8822  , 86040]
plt.plot(x,y,'y',label='Maharashtra',linewidth=5)

x2 =['5',  '15',  '25',  '30']
y2 =[111151 ,     62778  ,  1510 ,  46863]
plt.plot(x2,y2,'c',label='Tamil Nadu',linewidth=5)


x3 =['5',  '15',  '25',  '30']
y3 =[99444  ,    71339   , 3067  , 25038]
plt.plot(x3,y3,'m',label='Delhi',linewidth=5)

x4 =['5',  '15',  '25',  '30']
y4 =[36123,      25900   , 1944 ,   8279]
plt.plot(x4,y4,'g',label='Gujarat',linewidth=5)

x5=['5',  '15',  '25',  '30']
y5 =[27707,      18761  ,   785  ,  8161]
plt.plot(x5,y5,'r',label='Uttar Pradesh ',linewidth=5)

x6 =['5',  '15',  '25',  '30']
y6 =[20263  ,    15965  ,   459   , 3839]
plt.plot(x6,y6,'b',label='Rajasthan',linewidth=5)

x7 =['5',  '15',  '25',  '30']
y7 =[  22126,      14711  ,   757,    6658]
plt.plot(x7,y7,'k',label='West Bengal',linewidth=5)

x8 =['5',  '15',  '25',  '30']
y8 =[14930,      11411 ,    608  ,  2911]
plt.plot(x8,y8,'w',label='Madhya Pradesh',linewidth=5)


plt.title('state wise Report')
plt.ylabel('Confirmed  Recovered  Death Active')
plt.xlabel('1st to30 june2020')
plt.legend()
plt.show()
